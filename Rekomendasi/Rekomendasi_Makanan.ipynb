# %%
import pandas as pd
import numpy as np

# %%
food_data = pd.read_csv('/content/data_nutrisi_2.csv')

# %%
food_data = food_data.drop('air', axis = 1)

# %%
food_data
# Out:
#                   makanan  kalori  protein  lemak  karbohidrat  serat  \
# 0                    Nasi     180      3.0    0.3         39.8    0.2
# 1                Nasi tim     120      2.4    0.4         26.0    0.5
# 2             Tapai beras      99      1.7    0.3         22.4    0.0
# 3        Nasi beras merah     149      2.8    0.4         32.5    0.3
# 4     Bihun goreng instan     381      6.1    3.9         80.3    0.0
# ..                    ...     ...      ...    ...          ...    ...
# 587      Sukun tua, segar     126      1.6    0.2         24.5    1.5
# 588          Vigus, segar      44      2.4    0.1          8.3    0.0
# 589           Wani, segar      74      0.8    0.3         17.1    3.1
# 590  Mentimun Suri, segar      16      1.3    0.0          2.1    0.9
# 591         Blewah, segar      34      0.8    0.2          8.2    0.9
#
#      Kategori vegan/nonvegan
# 0    Serealia          Vegan
# 1    Serealia          Vegan
# 2    Serealia          Vegan
# 3    Serealia          Vegan
# 4    Serealia          Vegan
# ..        ...            ...
# 587      Buah          Vegan
# 588      Buah          Vegan
# 589      Buah          Vegan
# 590      Buah          Vegan
# 591      Buah          Vegan
#
# [592 rows x 8 columns]

# %%
numeric_cols = ['protein', 'lemak', 'karbohidrat', 'serat']

def get_top_2_nutrients(row):
    numeric_values = row[numeric_cols].apply(pd.to_numeric, errors='coerce')
    numeric_values = numeric_values.dropna()
    if len(numeric_values) < 2:
        return ''
    top_2 = numeric_values.nlargest(2)
    return ', '.join(top_2.index)

food_data['2_nutrisi_paling_banyak'] = food_data.apply(get_top_2_nutrients, axis=1)

food_data
# Out:
#                   makanan  kalori  protein  lemak  karbohidrat  serat  \
# 0                    Nasi     180      3.0    0.3         39.8    0.2
# 1                Nasi tim     120      2.4    0.4         26.0    0.5
# 2             Tapai beras      99      1.7    0.3         22.4    0.0
# 3        Nasi beras merah     149      2.8    0.4         32.5    0.3
# 4     Bihun goreng instan     381      6.1    3.9         80.3    0.0
# ..                    ...     ...      ...    ...          ...    ...
# 587      Sukun tua, segar     126      1.6    0.2         24.5    1.5
# 588          Vigus, segar      44      2.4    0.1          8.3    0.0
# 589           Wani, segar      74      0.8    0.3         17.1    3.1
# 590  Mentimun Suri, segar      16      1.3    0.0          2.1    0.9
# 591         Blewah, segar      34      0.8    0.2          8.2    0.9
#
#      Kategori vegan/nonvegan 2_nutrisi_paling_banyak
# 0    Serealia          Vegan    karbohidrat, protein
# 1    Serealia          Vegan    karbohidrat, protein
# 2    Serealia          Vegan    karbohidrat, protein
# 3    Serealia          Vegan    karbohidrat, protein
# 4    Serealia          Vegan    karbohidrat, protein
# ..        ...            ...                     ...
# 587      Buah          Vegan    karbohidrat, protein
# 588      Buah          Vegan    karbohidrat, protein
# 589      Buah          Vegan      karbohidrat, serat
# 590      Buah          Vegan    karbohidrat, protein
# 591      Buah          Vegan      karbohidrat, serat
#
# [592 rows x 9 columns]

# %%
food_data = food_data.drop(['kalori', 'protein', 'lemak', 'karbohidrat', 'serat'], axis =1)

# %%
food_data.columns
# Out:
# Index(['makanan', 'Kategori', 'vegan/nonvegan', '2_nutrisi_paling_banyak'], dtype='object')

# %%
food_data['tag'] = ''

for index,row in food_data.iterrows():
    vegan = ' '.join(row['vegan/nonvegan'].split(',')).lower()
    nutrisi = ' '.join(row['2_nutrisi_paling_banyak'].replace(' ','').split(',')).lower()
    row['tag'] =  vegan + ' ' + nutrisi 

recommend = food_data[['makanan','Kategori','tag']]
recommend
# Out:
#                   makanan  Kategori                        tag
# 0                    Nasi  Serealia  vegan karbohidrat protein
# 1                Nasi tim  Serealia  vegan karbohidrat protein
# 2             Tapai beras  Serealia  vegan karbohidrat protein
# 3        Nasi beras merah  Serealia  vegan karbohidrat protein
# 4     Bihun goreng instan  Serealia  vegan karbohidrat protein
# ..                    ...       ...                        ...
# 587      Sukun tua, segar      Buah  vegan karbohidrat protein
# 588          Vigus, segar      Buah  vegan karbohidrat protein
# 589           Wani, segar      Buah    vegan karbohidrat serat
# 590  Mentimun Suri, segar      Buah  vegan karbohidrat protein
# 591         Blewah, segar      Buah    vegan karbohidrat serat
#
# [592 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors


selected_features = ['Kategori', 'tag']

features = recommend[selected_features]
vectorizer = TfidfVectorizer()
tf_idf_tag = vectorizer.fit_transform(features['tag'])
features['tf_idf_tag'] = [v.toarray() for v in tf_idf_tag]
tf_idf_tag_array = np.concatenate(features['tf_idf_tag'], axis=0)
model = NearestNeighbors(n_neighbors=10, metric='cosine')


model.fit(tf_idf_tag_array)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=10)

# %%
user_input = ['vegan', 'karbohidrat lemak', 'pedas']
user_input = ' '.join(user_input)

user_input_tf_idf = vectorizer.transform([user_input]).toarray()


distances, indices = model.kneighbors(user_input_tf_idf)

top_10_food = food_data.iloc[indices[0]]

top_10_food
# Out:
#                      makanan Kategori vegan/nonvegan 2_nutrisi_paling_banyak  \
# 477              Uli batatas     Umbi          Vegan      karbohidrat, lemak
# 166                 Woku ubi    Sayur          Vegan      karbohidrat, lemak
# 472  Serimping talas kebumen     Umbi          Vegan      karbohidrat, lemak
# 475             Tiwul Instan     Umbi          Vegan      karbohidrat, lemak
# 469               Sagu manis     Umbi          Vegan      karbohidrat, lemak
# 478           Alpukat, segar     Buah          Vegan      karbohidrat, lemak
# 164    Tumis bayam bersantan    Sayur          Vegan      lemak, karbohidrat
# 468   Sagu Lemak (Kue Sagon)     Umbi          Vegan      karbohidrat, lemak
# 162            Semur jengkol    Sayur          Vegan      karbohidrat, lemak
# 471              Sagu sinole     Umbi          Vegan      karbohidrat, lemak
#
#                          tag
# 477  vegan karbohidrat lemak
# 166  vegan karbohidrat lemak
# 472  vegan karbohidrat lemak
# 475  vegan karbohidrat lemak
# 469  vegan karbohidrat lemak
# 478  vegan karbohidrat lemak
# 164  vegan lemak karbohidrat
# 468  vegan karbohidrat lemak
# 162  vegan karbohidrat lemak
# 471  vegan karbohidrat lemak
