# %%
# Install bing image downloader
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Buat direktori untuk menyimpan dataset
# !mkdir indonesian_food

# %%
from bing_image_downloader import downloader
import http.client as httplib
def download(apa_yang_mau_didownload, limit, output_dir='indonesian_food'):
    try:
        downloader.download(apa_yang_mau_didownload, limit=limit, output_dir=output_dir, adult_filter_off=True)
    except httplib.IncompleteRead as e:
        print("IncompleteRead error occurred:", str(e))

# %%
# %%capture
download('seblak', 400)

# %%
# %%capture
download('soto ayam', 400)

# %%
# %%capture
download('tempe goreng', 400)

# %%
# %%capture
download('nasi goreng', 400)

# %%
# %%capture
download('ayam geprek', 400)

# %%
# %%capture
download('mie ayam', 250)

# %%
# %%capture
download('sayur asem', 250)

# %%
# !zip -r '/content/indonesian_food.zip' '/content/indonesian_food'
# Out:
#   adding: content/indonesian_food/ (stored 0%)
#   adding: content/indonesian_food/seblak/ (stored 0%)
#   adding: content/indonesian_food/seblak/Image_142.jpg (deflated 4%)
#   adding: content/indonesian_food/seblak/Image_167.png (deflated 0%)
#   adding: content/indonesian_food/seblak/Image_44.jpg (deflated 0%)
#   adding: content/indonesian_food/seblak/Image_109.jpg (deflated 1%)
#   adding: content/indonesian_food/seblak/Image_10.jpg (deflated 0%)
#   adding: content/indonesian_food/seblak/Image_132.JPG (deflated 1%)
#   adding: content/indonesian_food/seblak/Image_146.jpg (deflated 0%)
#   adding: content/indonesian_food/seblak/Image_158.jpg (deflated 1%)
#   adding: content/indonesian_food/seblak/Image_59.jpg (deflated 1%)
#   adding: content/indonesian_food/seblak/Image_135.jpg (deflated 10%)
#   adding: content/indonesian_food/seblak/Image_118.jpg (deflated 9%)
#   adding: content/indonesian_food/seblak/Image_70.jpg (deflated 4%)
# ...
